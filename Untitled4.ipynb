# %% [markdown]
# <a href="https://colab.research.google.com/github/olgatar999/DataAnalysis-St/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
titanic = pd.read_excel('https://raw.githubusercontent.com/mattharrison/datasets/master/data/titanic3.xls')
titanic_not_Q = titanic.loc[titanic['embarked'] != 'Q']
titanic_not_Q['embarked'].unique()

len(titanic_not_Q)
titanic_not_Q.shape[0]

#titanic.loc[titanic.fare.isna() | (titanic.fare == 0)]

titanic['fare'].isna().sum()

(titanic['fare'] == 0).sum()
(titanic['sex'] == 'male').sum()
# Out:
# np.int64(843)
